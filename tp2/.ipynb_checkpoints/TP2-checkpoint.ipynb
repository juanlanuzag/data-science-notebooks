# %%
import scipy.io as sio
import pandas as pd
from scipy.signal import welch
from scipy.fftpack import rfft
import numpy as np
from matplotlib import pyplot as pl
import seaborn as sns
from scipy.interpolate import interp1d


pl.rcParams['figure.figsize'] = (10, 6)

# %%
p1 = sio.loadmat('dataset/S01.mat')

# %%
array  = p1['data']
# una matriz tridimensional: trials/epochs x electrodos x muestras en Epoch

# %% [markdown]
# ### Tomamos un epoch del electrodo 8 de una persona y calculamos welch

# %%
muestras8= array[:,8][0]
muestras8
pl.plot(muestras8)
pl.show()

# %%
ff= welch(muestras8, fs=250, nperseg=201)
ff
# pl.xlim(0.000125,0.0002)
pl.plot(ff[0],ff[1])
pl.show()

# %% [markdown]
# ### Comparo los graficos de las frecuencias con picos con la medicion del electrodo

# %%
omega = ff[0][31]
pl.plot(muestras8)
# pl.plot([np.sin(x*ff[0][1]) for x in range(0,201)])
# pl.plot([0.000010*np.sin(x/omega) for x in range(0,201)])
pl.show()

# %% [markdown]
# ### Intentamos promediando los epochs para un electrodo

# %%
for i in [8,44,80, 131,185]:
    muestras= array[:,i].mean(axis=0)
    pl.plot(muestras, label="Electrodo {}".format(i))
pl.legend(loc='best')
pl.show()

# %%
electrodos = [8,44,80, 131,185]
muestras = np.array([0]*201)
for i in electrodos:
    muestras = np.add(muestras,array[:,i])
muestras = muestras/len(electrodos)
# muestras= array[:,8]
fouriers = []
matriz = []
for i in range(len(muestras)):
     freqs, pot = welch(muestras[i], fs=250)
     matriz.append(pot)
npmatriz = np.array(matriz)
# Out:
# /usr/local/lib/python2.7/dist-packages/scipy/signal/spectral.py:1633: UserWarning: nperseg = 256 is greater than input length  = 201, using nperseg = 201
#   .format(nperseg, input_length))

# %%
ax = sns.heatmap(npmatriz.transpose()[0:40], cmap="viridis", vmax=1e-11)
freqs = [freq for freq in freqs if freq<50]
freqs = [int(freq*10)/10.0 for freq in freqs]
freqs = [freqs[i] for i in range(len(freqs)) if i%2==0]
ax.set_yticklabels(freqs, rotation='horizontal')
pl.show()

# %%
# una matriz tridimensional: trials/epochs x electrodos x muestras en Epoch
filenamesP = ['dataset/P0'+str(i)+'.mat' for i in range(1,10)]+['dataset/P10.mat']
filenamesS = ['dataset/S0'+str(i)+'.mat' for i in range(1,10)]+['dataset/S10.mat']
freqPotXPersona = []
for filename in filenamesS:
    array = sio.loadmat(filename)['data']
    ffs = []
    for i in range(256):
        muestras= array[:,i][0]
        ff= welch(muestras, fs=250, nperseg=201)
        ffs.append(ff[1])
        #pl.plot(ff[0],ff[1])
    frecuencia = ff[0]
    arrayffs = np.array(ffs)
    freqPotXPersona.append((frecuencia,arrayffs.mean(axis=0)))
for index, freqPot in enumerate(freqPotXPersona):
    pl.plot(freqPot[0],freqPot[1], label='S'+str(index+1))
pl.legend(loc='best')
pl.xlim(0,50)
pl.show()

# %%
def FrecuenciasPorTipo(archivos):
    freqPotXPersona = []
    for filename in archivos:
        array = sio.loadmat(filename)['data']
        ffs = []
        for i in range(256):
            muestras= array[:,i][0]
            ff= welch(muestras, fs=250, nperseg=201)
            ffs.append(ff[1])
        frecuencia = ff[0]
        arrayffs = np.array(ffs)
        freqPotXPersona.append((frecuencia,arrayffs.mean(axis=0)))
    for index, freqPot in enumerate(freqPotXPersona):
        pl.plot(freqPot[0],freqPot[1], label='S'+str(index+1))
    pl.legend(loc='best')
    pl.xlim(0,50)
    pl.show()
    
    return freqPotXPersona

def PromedioBandas(freqPotXPersona):
    proms = []#
    for j in range(len(freqPotXPersona)):
        proms.append([])
        freqPot = freqPotXPersona[j]
        buckets = [0,0,0,0,0]
        count = [0,0,0,0,0]
    
        for i in range(len(freqPot[1])):
            if freqPot[0][i] < 4:
                buckets[0] += freqPot[1][i]
                count[0] +=1
            elif freqPot[0][i] < 8:
                buckets[1] += freqPot[1][i]
                count[1] +=1
            elif freqPot[0][i] < 13:
                buckets[2] += freqPot[1][i]
                count[2] +=1
            elif freqPot[0][i] < 30:
                buckets[3] += freqPot[1][i]
                count[3] +=1
            else:
                buckets[4] += freqPot[1][i]
                count[4] +=1

        
        for i in range(len(buckets)):
            proms[j].append(buckets[i]/count[i])
    
    return proms

# %%
frecuenciasP = FrecuenciasPorTipo(filenamesP)
frecuenciasS = FrecuenciasPorTipo(filenamesS)

bandasP = PromedioBandas(frecuenciasP)
bandasS = PromedioBandas(frecuenciasS)

# %%
tablaP = pd.DataFrame(bandasP, columns=['delta', 'epsilon', 'alfa', 'beta', 'gamma'], index=['P'+str(i) for i in range(1,11)])
tablaS = pd.DataFrame(bandasS, columns=['delta', 'epsilon', 'alfa', 'beta', 'gamma'], index=['S'+str(i) for i in range(1,11)])

display(tablaP['alfa'])
display(tablaS['alfa'])

sns.swarmplot([tablaP['alfa'], tablaS['alfa']])
# Out:
# P1     8.597311e-13
# P2     9.486518e-13
# P3     4.638416e-13
# P4     6.338850e-13
# P5     9.192861e-13
# P6     9.813531e-13
# P7     8.245702e-13
# P8     1.586481e-13
# P9     1.409964e-12
# P10    7.654888e-13
# Name: alfa, dtype: float64
# S1     2.723230e-13
# S2     4.376674e-12
# S3     1.572334e-12
# S4     4.259952e-12
# S5     7.014281e-12
# S6     1.398234e-12
# S7     6.920435e-13
# S8     2.246092e-12
# S9     4.406465e-13
# S10    3.138754e-13
# Name: alfa, dtype: float64
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-b8189d04c032> in <module>()
#       5 display(tablaS['alfa'])
#       6
# ----> 7 sns.swarmplot([tablaP['alfa'], tablaS['alfa']])
#
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.pyc in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2779                        linewidth=linewidth))
#    2780
# -> 2781     plotter.plot(ax, kwargs)
#    2782     return ax
#    2783
#
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.pyc in plot(self, ax, kws)
#    1423     def plot(self, ax, kws):
#    1424         """Make the full plot."""
# -> 1425         self.draw_swarmplot(ax, kws)
#    1426         self.add_legend_data(ax)
#    1427         self.annotate_axes(ax)
#
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.pyc in draw_swarmplot(self, ax, kws)
#    1372                     # hue_mask = np.in1d(self.plot_hues[i], self.hue_names)
#    1373
# -> 1374                 swarm_data = group_data[hue_mask]
#    1375
#    1376                 # Sort the points for the beeswarm algorithm
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 2 but corresponding boolean dimension is 20
